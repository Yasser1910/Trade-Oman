# %% [markdown]
# <a href="https://colab.research.google.com/github/Yasser1910/Trade-Oman/blob/main/oman_export_products_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import io, requests, certifi
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

pd.set_option("display.float_format", lambda x: f"{x:,.0f}")

# %%
import pandas as pd


url = "https://raw.githubusercontent.com/Yasser1910/Trade-Oman/refs/heads/main/oman_export_products.csv"



df = pd.read_csv("https://raw.githubusercontent.com/Yasser1910/Trade-Oman/refs/heads/main/oman_export_products.csv")

print("✅ Loaded from GitHub:", df.shape)
df.head(5)
# Out:
# ✅ Loaded from GitHub: (99127, 12)
#    year trade_type   hs_code                                      hs_name  \
# 0  1998     Export 1,012,110                Purebred Horses Of Arab breed
# 1  1998     Export 1,019,000                       Live Mules And Hinnies
# 2  1998     Export 1,022,100                 PureBred Cattle For Breeding
# 3  1998     Export 1,029,000  Live Bovine Animals Excl Cattle And Buffalo
# 4  1998     Export 1,042,010                 Live PureBred Breeding Goats
#
#    value_omr  date  hs_code_full  hs_full_int  section_code_2  \
# 0     20,300  1998      10121100     10121100               2
# 1          7  1998      10190000     10190000               2
# 2     19,350  1998      10221000     10221000               2
# 3     16,970  1998      10290000     10290000               2
# 4  1,220,112  1998      10420100     10420100               2
#
#          section_name  section_name_clean         bec_broad
# ...

# %%
# normalize column names
df.columns = [c.strip().lower().replace(" ", "_") for c in df.columns]

# common columns expected: year, trade_type, hs_code, hs_name, value_omr
# (plus: section_name_clean, bec_broad if present)
df["year"] = pd.to_numeric(df.get("year"), errors="coerce").astype("Int64")
df["trade_type"] = df.get("trade_type").astype(str).str.title()
df["hs_code"] = df.get("hs_code").astype(str).str.strip()
df["value_omr"] = pd.to_numeric(df.get("value_omr"), errors="coerce").fillna(0.0)

# oil flag: HS 27 = Oil
# Step — Refine oil_flag for Exports

# list of HS codes to be treated as oil products (and excluded from Non-Oil Exports)
oil_hs_codes = [
    "27073000","27075000","27090000","27101211","27101213","27101214",
    "27101219","27101221","27101239","27101249","27111100","27111900",
    "27131100","27132000","28030000","27139000","25030000","27101231",
    "27101213","27101219","27101223","27101222","49070031","29024300","29022000"
]

# Convert to string (in case some are numeric)
df["hs_code_full"] = df["hs_code_full"].astype(str).str.strip()

# Mark Oil Products
df["oil_flag"] = np.where(
    (df["trade_type"].str.lower() == "export") & (df["hs_code_full"].isin(oil_hs_codes)),
    "Oil (HS 27)",
    "Non-Oil"
)

# Optional: verify counts
print(df["oil_flag"].value_counts())


print("✅ Cleaned. Columns:", list(df.columns))
df.sample(5)
# Out:
# oil_flag
# Non-Oil        98892
# Oil (HS 27)      235
# Name: count, dtype: int64
# ✅ Cleaned. Columns: ['year', 'trade_type', 'hs_code', 'hs_name', 'value_omr', 'date', 'hs_code_full', 'hs_full_int', 'section_code_2', 'section_name', 'section_name_clean', 'bec_broad', 'oil_flag']
#        year trade_type     hs_code  \
# 31683  2012  Re-Export  85437090.0
# 41226  2015     Export  52041900.0
# 3282   2000  Re-Export   3063200.0
# 57775  2018  Re-Export  32141091.0
# 60031  2018  Re-Export  84251900.0
#
#                                                  hs_name  value_omr  date  \
# 31683                               Proximity Cards Tags     59,246  2012
# 41226  Sewing Thread Containing Predominantly But 85 ...     43,922  2015
# 3282                      Not frozenLobsters Homarus spp     28,996  2000
# 57775  Mastics Based On Zinc Oxide Glycerol Used To M...     17,000  2018
# 60031  Pulley Tackle And Hoists Other Than Skip Hoist...    267,846  2018
#
# ...

# %%
# Total Exports = Export + Re-Export (imports excluded)
exports_plus_re = df[df["trade_type"].isin(["Export", "Re-Export"])].copy()
total = (exports_plus_re.groupby("year", as_index=False)["value_omr"]
         .sum().rename(columns={"value_omr":"Total_Exports_All"}))

# Non-Oil (Export only)
non_oil = (df[(df["trade_type"]=="Export") & (df["oil_flag"]=="Non-Oil")]
           .groupby("year", as_index=False)["value_omr"].sum()
           .rename(columns={"value_omr":"NonOil_Exports"}))

# Oil (Export only)
oil = (df[(df["trade_type"]=="Export") & (df["oil_flag"]=="Oil (HS 27)")]
       .groupby("year", as_index=False)["value_omr"].sum()
       .rename(columns={"value_omr":"Oil_Exports"}))

# merge & compute shares/YoY
series = (total.merge(non_oil, on="year", how="outer")
               .merge(oil, on="year", how="outer")
               .fillna(0.0).sort_values("year"))

series["NonOil_Share_pct"] = np.where(series["Total_Exports_All"]>0,
                                      series["NonOil_Exports"]/series["Total_Exports_All"]*100, np.nan)
series["YoY_Total_%"]  = series["Total_Exports_All"].pct_change()*100
series["YoY_NonOil_%"] = series["NonOil_Exports"].pct_change()*100
series["YoY_Oil_%"]    = series["Oil_Exports"].pct_change()*100

series.head(10)
# Out:
#    year  Total_Exports_All  NonOil_Exports   Oil_Exports  NonOil_Share_pct  \
# 0  1998      2,071,803,925     199,309,021 1,379,239,999                10
# 1  1999      2,727,083,011     201,111,139 2,070,627,428                 7
# 2  2000      4,281,139,167     246,722,155 3,535,784,032                 6
# 3  2001      4,229,515,282     265,156,341 3,386,747,630                 6
# 4  2002      4,257,236,204     259,082,468 3,271,450,151                 6
# 5  2003      4,425,279,368     299,272,282 3,525,237,535                 7
# 6  2004      5,083,561,968     416,564,033 4,128,709,048                 8
# 7  2005      7,114,460,435     554,731,657 5,975,821,563                 8
# 8  2006      8,370,404,461     665,620,986 6,937,838,169                 8
# 9  2007      9,157,238,607   1,048,199,145 7,105,545,163                11
#
#    YoY_Total_%  YoY_NonOil_%  YoY_Oil_%
# 0          NaN           NaN        NaN
# 1           32             1         50
# ...

# %%
# 4.1 Total vs Non-Oil (levels)
fig1 = go.Figure()
fig1.add_scatter(x=series["year"], y=series["Total_Exports_All"], mode="lines+markers",
                 name="Total Exports (Export + Re-Export)", line=dict(width=3))
fig1.add_scatter(x=series["year"], y=series["NonOil_Exports"], mode="lines+markers",
                 name="Non-Oil Exports (Export only)", line=dict(width=3))
fig1.update_layout(title="Total vs Non-Oil Exports (Imports excluded from total)",
                   xaxis_title="Year", yaxis_title="OMR", template="plotly_white")
fig1.show()

# 4.2 Non-oil share of total
fig2 = px.line(series, x="year", y="NonOil_Share_pct", markers=True,
               title="Non-Oil Exports as % of Total Exports (Export + Re-Export)")
fig2.update_traces(line=dict(width=3), marker=dict(size=8))
fig2.update_layout(template="plotly_white", yaxis_title="Share (%)")
fig2.show()

# 4.3 YoY growth
fig3 = go.Figure()
for col, name in [("YoY_Total_%","Total"),("YoY_NonOil_%","Non-Oil"),("YoY_Oil_%","Oil")]:
    fig3.add_scatter(x=series["year"], y=series[col], mode="lines+markers", name=name)
fig3.add_hline(y=0, line_dash="dot", line_color="gray")
fig3.update_layout(title="YoY Growth (Totals exclude Imports)",
                   xaxis_title="Year", yaxis_title="YoY Growth (%)", template="plotly_white")
fig3.show()

# 4.4 product counts (Export only)
exp_only = df[df["trade_type"]=="Export"]
counts = (exp_only[exp_only["value_omr"]>0]
          .groupby(["year","oil_flag"])["hs_code"].nunique()
          .reset_index())
fig4 = px.line(counts, x="year", y="hs_code", color="oil_flag", markers=True,
               title="Number of Products Exported (Export only)")
fig4.update_traces(line=dict(width=3))
fig4.update_layout(template="plotly_white", yaxis_title="Unique HS Codes")
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Non-Oil by BEC (Export only)
non_oil_bec = (df[(df["trade_type"]=="Export") & (df["oil_flag"]=="Non-Oil")]
               .groupby(["year","bec_broad"], as_index=False)["value_omr"].sum())

# Total by BEC = Export + Re-Export (imports excluded)
total_bec = (df[df["trade_type"].isin(["Export","Re-Export"])]
             .groupby(["year","bec_broad"], as_index=False)["value_omr"].sum())

def stacked_area(df_bec, title):
    wide = df_bec.pivot(index="year", columns="bec_broad", values="value_omr").fillna(0).sort_index()
    fig = go.Figure()
    for col in wide.columns:
        fig.add_scatter(x=wide.index, y=wide[col], stackgroup="one", name=col)
    fig.update_layout(title=title, xaxis_title="Year", yaxis_title="OMR", template="plotly_white")
    fig.show()

stacked_area(non_oil_bec, "Non-Oil Exports by BEC (Export only)")
stacked_area(total_bec,   "Total Exports by BEC (Export + Re-Export; Imports EXCLUDED)")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
latest_year = int(df["year"].dropna().max()); prev_year = latest_year - 1
non_oil_export = df[(df["trade_type"]=="Export") & (df["oil_flag"]=="Non-Oil")].copy()

cur = (non_oil_export[non_oil_export["year"]==latest_year]
       .groupby(["hs_code","hs_name"], as_index=False)["value_omr"].sum()
       .rename(columns={"value_omr":"value_curr"}))

prev = (non_oil_export[non_oil_export["year"]==prev_year]
        .groupby(["hs_code","hs_name"], as_index=False)["value_omr"].sum()
        .rename(columns={"value_omr":"value_prev"}))

prod = cur.merge(prev, on=["hs_code","hs_name"], how="left").fillna({"value_prev":0.0})
prod["abs_delta"] = prod["value_curr"] - prod["value_prev"]
prod["yoy_pct"] = np.where(prod["value_prev"]>0, prod["abs_delta"]/prod["value_prev"]*100, np.nan)

top_val  = prod.sort_values("value_curr", ascending=False).head(10)
top_grow = prod.sort_values("abs_delta", ascending=False).head(10)

top_val[["hs_code","hs_name","value_curr","value_prev","abs_delta","yoy_pct"]]
# Out:
#          hs_code                                            hs_name  \
# 292   27101212.0                                      Whole Naphtha
# 273   26011200.0  Agglomerated Iron Ores And Concentrates Excl R...
# 379   31021000.0  Urea Whether Or Not In Aqueous Solution Excl T...
# 1063  72142040.0  Other bars and rods of iron or nonalloy steel ...
# 342   29051100.0                            Methanol Methyl Alcohol
# 1227  76011000.0                    Aluminium Not Alloyed Unwrought
# 535   39076100.0  poly ethylene terephthalate Having a viscosity...
# 569   39206200.0  Plates Sheets Film Foil And Strip Of NonCellul...
# 1033  72071100.0  SemiFinished Products Of Iron Or NonAlloy Stee...
# 522   39021000.0                     Polypropylene In Primary Forms
#
#       value_curr  value_prev   abs_delta  yoy_pct
# 292  692,534,116 163,310,643 529,223,473      324
# 273  674,724,865 635,262,553  39,462,312        6
# 379  421,099,044 418,104,969   2,994,075        1
# ...

# %%
no_sec = (df[(df["trade_type"]=="Export") & (df["oil_flag"]=="Non-Oil")]
          .groupby(["year","section_name_clean"], as_index=False)["value_omr"].sum())
no_tot = (df[(df["trade_type"]=="Export") & (df["oil_flag"]=="Non-Oil")]
          .groupby("year", as_index=False)["value_omr"].sum()
          .rename(columns={"value_omr":"non_oil_total"}))

pivot_sec = no_sec.pivot(index="year", columns="section_name_clean", values="value_omr").fillna(0.0).sort_index()
pivot_sec = pivot_sec.merge(no_tot.set_index("year"), left_index=True, right_index=True, how="left")

pivot_sec["total_prev"] = pivot_sec["non_oil_total"].shift(1)
deltas = pivot_sec.drop(columns=["non_oil_total","total_prev"]).diff()
contrib_pp_sec = deltas.div(pivot_sec["total_prev"], axis=0) * 100

contrib_long = contrib_pp_sec.reset_index().melt(id_vars="year", var_name="HS Section", value_name="pp")
fig = px.bar(contrib_long, x="year", y="pp", color="HS Section",
             title="Contribution to Non-Oil Exports YoY Growth by HS Section (pp)",
             labels={"pp":"Percentage points"})
fig.update_layout(barmode="relative", template="plotly_white")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Diversification by number of products and HHI (Export only)
non_oil_exp = df[(df["trade_type"] == "Export") & (df["oil_flag"] == "Non-Oil")]

# total exports per year
total_by_year = non_oil_exp.groupby("year", as_index=False)["value_omr"].sum().rename(columns={"value_omr":"total_value"})

# number of HS codes per year
num_products = (non_oil_exp.groupby("year")["hs_code"].nunique().reset_index().rename(columns={"hs_code":"num_products"}))

# HHI = sum of (share^2)
shares = non_oil_exp.merge(total_by_year, on="year", how="left")
shares["share"] = shares["value_omr"] / shares["total_value"]
hhi = (shares.groupby("year")["share"].apply(lambda x: (x**2).sum()).reset_index().rename(columns={"share":"HHI"}))

# Merge together
div_index = total_by_year.merge(num_products, on="year").merge(hhi, on="year")

# Normalized diversification index = (1 - HHI)
div_index["Diversification_Index"] = 1 - div_index["HHI"]

div_index.head()
# Out:
#    year  total_value  num_products  HHI  Diversification_Index
# 0  1998  199,309,021           442    0                      1
# 1  1999  201,111,139           410    0                      1
# 2  2000  246,722,155           599    0                      1
# 3  2001  265,156,341           542    0                      1
# 4  2002  259,082,468           674    0                      1

# %%
fig = go.Figure()
fig.add_scatter(x=div_index["year"], y=div_index["num_products"], mode="lines+markers", name="No. of Products", yaxis="y1")
fig.add_scatter(x=div_index["year"], y=div_index["Diversification_Index"], mode="lines+markers", name="Diversification Index", yaxis="y2")

fig.update_layout(
    title="Non-Oil Export Diversification — Number of Products & HHI-based Index",
    xaxis=dict(title="Year"),
    yaxis=dict(title="No. of Products"),
    yaxis2=dict(title="Diversification Index (1−HHI)", overlaying="y", side="right"),
    template="plotly_white"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Theil index: T = Σ (p_i * ln(p_i / mean_p))
from numpy import log

shares = non_oil_exp.merge(total_by_year, on="year", how="left")
shares["p_i"] = shares["value_omr"] / shares["total_value"]

def theil(x):
    x = x[x > 0]
    mean_x = x.mean()
    return (x * np.log(x / mean_x)).sum()

theil_idx = shares.groupby("year")["p_i"].apply(theil).reset_index().rename(columns={"p_i":"Theil_Index"})

div_index = div_index.merge(theil_idx, on="year", how="left")
div_index.head()
# Out:
#    year  total_value  num_products  HHI  Diversification_Index  Theil_Index
# 0  1998  199,309,021           442    0                      1            2
# 1  1999  201,111,139           410    0                      1            2
# 2  2000  246,722,155           599    0                      1            2
# 3  2001  265,156,341           542    0                      1            2
# 4  2002  259,082,468           674    0                      1            2

# %%
div_table = (div_index.assign(period=lambda x: (x["year"]//5)*5)
             .groupby("period", as_index=False)
             .agg({"num_products":"mean", "HHI":"mean", "Diversification_Index":"mean", "Theil_Index":"mean"}))

div_table.rename(columns={"period":"Period (5-Year Avg)",
                          "num_products":"Avg. Products",
                          "HHI":"Avg. HHI",
                          "Diversification_Index":"Avg. (1−HHI)",
                          "Theil_Index":"Avg. Theil"}, inplace=True)

div_table.round(3)
# Out:
#    Period (5-Year Avg)  Avg. Products  Avg. HHI  Avg. (1−HHI)  Avg. Theil
# 0                 1995            426         0             1           2
# 1                 2000            638         0             1           2
# 2                 2005            641         0             1           2
# 3                 2010          1,362         0             1           3
# 4                 2015          1,768         0             1           3
# 5                 2020          2,071         0             1           4

# %%
# D5 — Share of Top 10 Products in Non-Oil Exports (by year)

# non_oil_exp and total_by_year are created in D1:
#   non_oil_exp = df[(df["trade_type"]=="Export") & (df["oil_flag"]=="Non-Oil")]
#   total_by_year = non_oil_exp.groupby("year", as_index=False)["value_omr"].sum().rename(columns={"value_omr":"total_value"})

# 1) value by HS & year
by_prod = (non_oil_exp
           .groupby(["year", "hs_code"], as_index=False)["value_omr"]
           .sum())

# 2) rank within each year (ties broken by first appearance)
by_prod["rank"] = by_prod.groupby("year")["value_omr"].rank(method="first", ascending=False)

# 3) keep top 10 per year (or fewer if not available)
top10 = by_prod[by_prod["rank"] <= 10]

# 4) aggregate top10 value per year
top10_sum = (top10.groupby("year", as_index=False)["value_omr"]
             .sum()
             .rename(columns={"value_omr":"top10_value"}))

# 5) merge with yearly totals and compute share
top10_share = top10_sum.merge(total_by_year, on="year", how="left")
top10_share["Top10_Share_pct"] = (top10_share["top10_value"] / top10_share["total_value"] * 100)

# optional sanity check
display(top10_share.sort_values("year").tail())

# 6) plot
fig = px.line(top10_share.sort_values("year"),
              x="year", y="Top10_Share_pct", markers=True,
              title="Share of Top 10 Products in Total Non-Oil Exports",
              labels={"Top10_Share_pct":"Share (%)"})
fig.update_layout(template="plotly_white", yaxis_tickformat=".1f")
fig.show()

fig.show()
# Out:
#     year   top10_value    total_value  Top10_Share_pct
# 22  2020 1,555,852,046  3,308,468,696               47
# 23  2021 2,458,492,928  4,866,459,130               51
# 24  2022 3,459,552,398  6,341,186,510               55
# 25  2023 3,826,029,524  7,100,009,295               54
# 26  2024 7,719,195,894 10,529,297,754               73
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Filter for non-oil exports only
non_oil_exp = df[(df["trade_type"] == "Export") & (df["oil_flag"] == "Non-Oil")]

# Choose analysis window — last year in dataset
latest_year = non_oil_exp["year"].max()
latest_data = non_oil_exp[non_oil_exp["year"] == latest_year]

# Top 20 products by value
top_products = (latest_data
                .groupby(["hs_code", "hs_name"], as_index=False)["value_omr"]
                .sum()
                .sort_values("value_omr", ascending=False)
                .head(20))

# Percentage share of total
total_value = latest_data["value_omr"].sum()
top_products["share_pct"] = top_products["value_omr"] / total_value * 100

# Display
top_products.head(10)
# Out:
#          hs_code                                            hs_name  \
# 292   27101212.0                                      Whole Naphtha
# 273   26011200.0  Agglomerated Iron Ores And Concentrates Excl R...
# 379   31021000.0  Urea Whether Or Not In Aqueous Solution Excl T...
# 1063  72142040.0  Other bars and rods of iron or nonalloy steel ...
# 342   29051100.0                            Methanol Methyl Alcohol
# 1227  76011000.0                    Aluminium Not Alloyed Unwrought
# 535   39076100.0  poly ethylene terephthalate Having a viscosity...
# 569   39206200.0  Plates Sheets Film Foil And Strip Of NonCellul...
# 1033  72071100.0  SemiFinished Products Of Iron Or NonAlloy Stee...
# 522   39021000.0                     Polypropylene In Primary Forms
#
#        value_omr  share_pct
# 292  692,534,116          7
# 273  674,724,865          6
# 379  421,099,044          4
# 1063 249,612,049          2
# 342  236,365,241          2
# 1227 222,067,770          2
# ...

# %%
fig = px.bar(top_products.sort_values("value_omr", ascending=True),
             x="value_omr", y="hs_name", orientation="h",
             title=f"Top 20 Non-Oil Export Products — {latest_year}",
             labels={"value_omr":"Value (OMR)", "hs_name":""})
fig.update_layout(template="plotly_white", height=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Aggregate yearly totals per product
prod_growth = (non_oil_exp
               .groupby(["hs_code", "hs_name", "year"], as_index=False)["value_omr"]
               .sum())

# Compute growth rates
def growth_rate(x):
    if len(x) < 2:
        return np.nan
    x = x.sort_values("year")
    first, last = x["value_omr"].iloc[0], x["value_omr"].iloc[-1]
    years = x["year"].iloc[-1] - x["year"].iloc[0]
    if first <= 0 or years == 0:
        return np.nan
    return ((last / first) ** (1 / years) - 1) * 100

growth = (prod_growth.groupby(["hs_code", "hs_name"])
          .apply(growth_rate)
          .reset_index(name="avg_annual_growth_pct")
          .dropna()
          .sort_values("avg_annual_growth_pct", ascending=False))

# Keep top 20 fastest growing
top_growers = growth.head(20)
top_growers.head(20)
# Out:
# /tmp/ipython-input-593038598.py:18: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#          hs_code                                            hs_name  \
# 511    2069011.0  Tongues Of Sheep Goats Frozen Fit Or Suitable ...
# 3970  83061000.0  Bells Gongs And The Like NonElectric Of Base M...
# 4466  85176990.0  Other Apparatus For Transmission Or Reception ...
# 3806  80070010.0  Vats Reservoirs Drums And Other Containers Not...
# 2061  44119200.0  Fibreboard Of Wood Or Other Ligneous Materials...
# 409   20059997.0                            Grape Leaves Not Frozen
# 4469  85182100.0    Single Loudspeakers Mounted In Their Enclosures
# ...

# %%
# Step P3 — Absolute growth with first & last year info

# 1. Filter Non-Oil Exports only
non_oil_exp = df[(df["trade_type"] == "Export") & (df["oil_flag"] == "Non-Oil")]

# 2. Aggregate yearly totals per product
prod_year = (non_oil_exp
             .groupby(["hs_code", "hs_name", "year"], as_index=False)["value_omr"]
             .sum()
             .sort_values(["hs_code", "year"]))

# 3. For each product, find first & last year values
def abs_growth_info(x):
    x = x.sort_values("year")
    first_year, last_year = x["year"].iloc[0], x["year"].iloc[-1]
    first_val, last_val = x["value_omr"].iloc[0], x["value_omr"].iloc[-1]
    abs_growth = last_val - first_val
    return pd.Series({
        "first_year": first_year,
        "last_year": last_year,
        "first_val": first_val,
        "last_val": last_val,
        "abs_growth": abs_growth
    })

growth_info = (prod_year.groupby(["hs_code", "hs_name"])
               .apply(abs_growth_info)
               .reset_index())

# 4. Sort by absolute growth (descending)
top_contributors = (growth_info
                    .sort_values("abs_growth", ascending=False)
                    .head(30))

# 5. Display table
top_contributors[["hs_code", "hs_name", "first_year", "last_year",
                  "first_val", "last_val", "abs_growth"]].head(30)
# Out:
# /tmp/ipython-input-3042555409.py:27: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#          hs_code                                            hs_name  \
# 761   27101212.0                                      Whole Naphtha
# 718   26011200.0  Agglomerated Iron Ores And Concentrates Excl R...
# 1322  31021000.0  Urea Whether Or Not In Aqueous Solution Excl T...
# 3394  72142040.0  Other bars and rods of iron or nonalloy steel ...
# 3715  76011000.0                    Aluminium Not Alloyed Unwrought
# 963   29051100.0                            Methanol Methyl Alcohol
# 1676  39076100.0  poly ethylene terephthalate Having a viscosity...
# ...

# %%
# Construct custom label with year range
top_contributors["label"] = (
    top_contributors["hs_name"] +
    " (" + top_contributors["first_year"].astype(str) +
    "–" + top_contributors["last_year"].astype(str) + ")"
)

fig = px.bar(top_contributors.sort_values("abs_growth", ascending=True),
             x="abs_growth", y="label", orientation="h",
             title="Top 20 Products by Absolute Contribution to Non-Oil Export Growth",
             labels={"abs_growth":"Change in Value (OMR)", "label":""})
fig.update_layout(template="plotly_white", height=650)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Step P4 — Export value over time for top contributors

# 1. Filter to top 20 contributing HS codes
top_codes = top_contributors.head(5)["hs_code"].unique()

# 2. Get their yearly values from non_oil_exp
trend_df = (non_oil_exp[non_oil_exp["hs_code"].isin(top_codes)]
            .groupby(["year", "hs_code", "hs_name"], as_index=False)["value_omr"]
            .sum())

# 3. Plotly line chart
fig = px.line(trend_df.sort_values("year"),
              x="year", y="value_omr",
              color="hs_name",
              title="Export Value Over Time — Top 5 Non-Oil Products by Growth Contribution",
              labels={"value_omr":"Value (OMR)", "year":"Year", "hs_name":"Product"})

fig.update_traces(mode="lines+markers")
fig.update_layout(template="plotly_white", height=650,
                  legend_title_text="Product",
                  hovermode="x unified")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
